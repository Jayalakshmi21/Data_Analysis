# %% [markdown]
# ### The Sparks Foundation
#
# TASK-3
#
# Exploratory Data Analysis on dataset SampleSuperstore
#
# Name: Jayalakshmi P.E
#
# GRIPOCTOBER23

# %% [markdown]
# Importing Libraries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r'C:\Users\DELL\Downloads\SampleSuperstore.csv'
df = pd.read_csv(file_path)
print("Data imported successfully")
df.head(10)
# Out:
# Data imported successfully
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# ...

# %% [markdown]
# Overview of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# Displaying the last few rows

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# Counting the number of missing (null or NaN) values in each column

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
#  Generating various summary statistics for numerical columns in a DataFrame

# %%
df.describe(include='all').T
# Out:
#                count unique              top  freq          mean          std  \
# Ship Mode       9994      4   Standard Class  5968           NaN          NaN
# Segment         9994      3         Consumer  5191           NaN          NaN
# Country         9994      1    United States  9994           NaN          NaN
# City            9994    531    New York City   915           NaN          NaN
# State           9994     49       California  2001           NaN          NaN
# Postal Code   9994.0    NaN              NaN   NaN  55190.379428  32063.69335
# Region          9994      4             West  3203           NaN          NaN
# Category        9994      3  Office Supplies  6026           NaN          NaN
# Sub-Category    9994     17          Binders  1523           NaN          NaN
# Sales         9994.0    NaN              NaN   NaN    229.858001   623.245101
# Quantity      9994.0    NaN              NaN   NaN      3.789574      2.22511
# ...

# %% [markdown]
# Separating and identifing categorical and numerical variables (columns) in the DataFrame

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category'],
#       dtype='object')
# Numerical Variables:
# ['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Postal Code
# Skew : -0.13
# Sales
# Skew : 12.97
# Quantity
# Skew : 1.28
# Discount
# Skew : 1.68
# Profit
# Skew : 7.56

# %%
# Create a 3x2 grid of subplots
fig, axes = plt.subplots(4, 2, figsize=(18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')

# Create countplots for each categorical variable
for i, var in enumerate(cat_cols):
    
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    sns.countplot(ax=axes[row, col], x=var, data=data, color='blue', order=data[var].value_counts().index)
    axes[row, col].tick_params(labelrotation=45) 
    if var in ['State']:
        axes[row, col].tick_params(labelrotation=90)  # Rotate x-axis labels by 90 degrees for better readability
        axes[row, col].tick_params(axis='x', labelsize=8) # Rotate x-axis labels for better readability

plt.tight_layout()  # Adjust subplot spacing
plt.show()

# %%
top_cities = data['City'].value_counts().head(20)

# Get the worst 20 cities by frequency
worst_cities = data['City'].value_counts().tail(20)

# Create subplots with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Plot the top 20 cities
sns.barplot(ax=axes[0], x=top_cities.values, y=top_cities.index)
axes[0].set_title('Top 20 Cities by Frequency')
axes[0].set_xlabel('Frequency')
axes[0].set_ylabel('City')
axes[0].tick_params(axis='y', labelrotation=0)  # Keep y-axis labels horizontal

# Plot the worst 20 cities
sns.barplot(ax=axes[1], x=worst_cities.values, y=worst_cities.index)
axes[1].set_title('Worst 20 Cities by Frequency')
axes[1].set_xlabel('Frequency')
axes[1].set_ylabel('City')
axes[1].tick_params(axis='y', labelrotation=0)  # Keep y-axis labels horizontal

plt.tight_layout()
plt.show()

# %% [markdown]
# Performing logarithmic transformation

# %%
def log_transform(data, col):
    for colname in col:
        valid_values = data[data[colname] > 0][colname]  
        data[colname + '_log'] = np.log1p(valid_values)

# %% [markdown]
# Filtering the data to remove rows with missing values in the 'Profit' column, then performs a logarithmic transformation on the 'Sales' and 'Profit' columns

# %%
data_filtered = data.dropna(subset=['Profit'])
log_transform(data_filtered, ['Sales', 'Profit'])
sns.displot(data=data_filtered, x="Sales_log", kde=True, bins=20)
plt.xlabel("Sales_log")
plt.ylabel("Density")
plt.title("Distribution of Sales_log")
# Out:
# Text(0.5, 1.0, 'Distribution of Sales_log')

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=data.drop(['Sales','Profit'],axis=1))
plt.show()

# %%
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))

# Features to plot against 'Profit'
features_to_plot = ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category']

# Loop through each feature and create a bar plot
for i, feature in enumerate(features_to_plot):
    # Group by the feature and calculate the mean of 'Profit', sorted in descending order
    data.groupby(feature)['Profit'].mean().sort_values(ascending=False).plot.bar(ax=axarr[i // 2][i % 2], fontsize=12)
    axarr[i // 2][i % 2].set_title(f"{feature} Vs Profit", fontsize=18)

# Adjust subplot spacing
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=0.5)

# Remove spines from plots
sns.despine()

# Show the plots
plt.show()

# %% [markdown]
# Representation of the mean profit for each state in the dataset, making it easy to compare and identify states with the highest and lowest mean profits

# %%
state_profit_means = data.groupby('State')['Profit'].mean().sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=state_profit_means.index, y=state_profit_means.values)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('State', fontsize=14)
plt.ylabel('Mean Profit', fontsize=14)
plt.title('Mean Profit by State', fontsize=18)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Representation of the total profit for the top 20 cities in the dataset, making it easy to identify cities with the highest total profits.

# %%
top_cities = data.groupby('City')['Profit'].sum().sort_values(ascending=False).head(20)

# Create a bar plot for the top N cities
plt.figure(figsize=(12, 8))
sns.barplot(x=top_cities.index, y=top_cities.values)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('City', fontsize=14)
plt.ylabel('Total Profit', fontsize=14)
plt.title('Top 20 Cities by Total Profit', fontsize=18)
plt.tight_layout()

# Show the plot
plt.show()
